# %%
print('Hola mundo')
# Out:
# Hola mundo

# %% [markdown]
# ## Challenge 1 🤺 10m
# Escribir un programa que cree un `diccionario vacío` y lo vaya llenado con información sobre una persona (por ejemplo nombre, edad, sexo, teléfono, correo electrónico, etc.) que se le `pida al usuario`.
#
# Cada vez que se `añada` un nuevo dato debe `imprimirse` el contenido del diccionario.

# %%
#Creo la lista mis_contactos
mis_contactos = {}

#Pido al usuario que ingrese su nombre
mis_contactos = {input("ingrese su nombre")}
print("Nombre:", mis_contactos)

mis_contactos = {input("ingrese su edad")}
print("Edad: ", mis_contactos)

mis_contactos = {input("ingrese su sexo")}
print("Sexo: ", mis_contactos)

mis_contactos = {input("ingrese su numero de telefono")}
print("Telefono: ", mis_contactos)

mis_contactos = {input("ingrese su correo electronico")}
print("Correo: ", mis_contactos)
# Out:
# Nombre: {'Alan'}
# Edad:  {'27'}
# Sexo:  {'Masculino'}
# Telefono:  {''}
# Correo:  {'alanlezcano@gmail.com'}

# %%
#Codigo del compañero Carlos
# Crear el diccionario vacio
dictionary = {}

# Agregar Nombre
dictionary['Nombre'] = input('Ingresa tu nombre')
print(dictionary)
# Agregar edad
dictionary['edad'] = input('Ingresa tu edad')
print(dictionary)
# Agregar ciudad
dictionary['ciudad'] = input('Ingresa tu ciudad')
print(dictionary)
# Agregar telefono
dictionary['telefono'] = input('Ingresa tu telefono')
print(dictionary)
# Agregar email
dictionary['email'] = input('Ingresa tu email')
print(dictionary)

# %% [markdown]
# ## Challenge 2 🤺 - 20 min
#
# Crear una tarjeta personal. El usuario (mediante `input`) puede elegir:
#
# 1. `Crear` datos nuevos
# 2. `Modificar` datos
# 3. `Eliminar` datos

# %%
#Creo la agenda vacia
agenda_personal = {}
agregar_datos = "agregar datos"
modificar_datos = "modificar datos"
eliminar_datos = "eliminar datos"
#Creo el input
agenda_personal
#Le doy opciones al usuario
while True:
    accion=int(input("que desea realizar,1=Agregar datos,2=Modificar,3=Eliminar "))
#Establezco las diferentes alternativas
    if agenda_personal == 1:
        agenda_personal ["Nombre"] = input("Ingrese su nombre")
        print(agenda_personal)
        agenda_personal ["Apellido"] = input("Ingrese su apellido")
        print(agenda_personal)
        agenda_personal ["Cargo"] = input("Ingrese su cargo")
        print(agenda_personal)
    elif agenda_personal == 2:
        agenda_personal ["Nombre"] = input("Ingrese nuevo nombre")
        print(agenda_personal)
        agenda_personal ["Apellido"] = input("Ingrese nuevo apellido")
        print(agenda_personal)
        agenda_personal["Cargo"] = input("Ingrese nuevo cargo")
        print(agenda_personal)
    elif agenda_personal == 3:
        eliminar_datos = input("eliminar datos")
        del (agenda_personal[])

# %%
#Solucion del compañero Hugo
tarjeta={}

while True:
    accion=int(input("que desea realizar,1=crear,2=modificar,3=eliminar "))
  
    if accion==1:
        clave_1=input("ingrese la clave")
        valor_1=input("ingrese el valor para la clave")
        tarjeta[clave_1]=valor_1
        print(tarjeta)
    elif accion==2:
        print("los valores que podes modificar son son")
        print(tarjeta.items())
        clave_1=input("ingrese la clave a cambiar")
        modificacion=input("ingrese el valor nuevo")
        tarjeta[clave_1]=modificacion
        print(tarjeta)
    elif accion==3:
        print("los valores que podes eliminar son")
        print(tarjeta.keys())
        clave_1=input("ingresa el valor a eliminar")
        del tarjeta[clave_1]
        print(tarjeta)
    parar=input("si desea salir ingrese si sino ingrese no")
    if parar=="si":
        break

# %% [markdown]
# ## Challenge 3 🤺
# Crear una agenda de contactos. El usuario puede elegir:
#
# 1. `Mostrar` los contactos
# 2. `Crear `contacto
# 3. `Modificar` datos del contacto

# %% [markdown]
# ## Challenge 4🤺  - 15 min
#
# Crear una clase animales que tenga atributo de clase y de instancia.
#
# - Atributos de clase: `especie`.
# - Atributos de instancia: `nombre` & `color`
# .
# Luego, crear nuevos objetos a partir de las nuevas class. Imprimir el nombre y el color de los animales en una frase.
# Ejemplo: "Me llamo `{nombre}` y soy un ave de color `{color}`".

# %%
class Eeveelution:
    #Atributos de clase
    especie = "pokemon"
#Creando un objeto
    def __init__(self, nombre, color, tipo):
        self.nombre = nombre
        self.color = color
        self.tipo = tipo
eevee = Eeveelution ("eevee", "marron", "normal")
umbreon = Eeveelution("umbreon", "negro", "siniestro")
jolteon = Eeveelution("jolteon", "amarillo", "electrico" )

print(f"El pokemon se llama {eevee.nombre}, es de tipo {eevee.tipo} y de color {eevee.color}")
print(f"El pokemon se llama {umbreon.color}, es de tipo {umbreon.tipo} y es de color {umbreon.color}")
print(f"El pokemon se llama {jolteon.color}, es de tipo {jolteon.tipo} y es de color {jolteon.color}")
# Out:
# El pokemon se llama eevee, es de tipo normal y de color marron
# El pokemon se llama negro, es de tipo siniestro y es de color negro
# El pokemon se llama amarillo, es de tipo electrico y es de color amarillo

# %% [markdown]
# ## Challenge 5🤺 - 15 min
# Crear dos métodos para nuestro animal y ejecutar, debe ser algo específico de ese animal.
#
# Ejemplo: "Cuando hablo, digo X".
# Ejemplo: "Cuando me muevo, hago X".

# %%
#Atributos de instancia
def __init__(self, ataque, posicion = "centro"):
    self.ataque = ataque
    self.posicion = posicion

#Definir acciones de clase
def atacar(self, metros):
    self.posicion += metros
print(f"El pokemon ataca")

# %% [markdown]
# Herencia

# %% [markdown]
# ## Challenge 6🤺 - 15 min
# Definir una clase madre que herede a sus clases hijas dos atributos de instancia. Mostrar ambos atributos en pantalla desde los objetos de las clases hijas.
#
# Observación: Editar las clases hijas para que no se inicialicen.

# %%
#Atributos de instancia
def __init__(self, nombre, color):
    self.nombre = nombre
    self.color = color

#Metodos (Acciones de la clase)
def presentarse(self):
    print(f"Hola, soy {self.nombre}")

def definirse(self):
    print(f"Soy de color {self.color}")

#Creo clases
class Caballo(Animal  de granja):

# %%
#Solucion del compañero GuilleLopez
class Persona:
  def __init__(self,nombre,edad):
    #atributos de instancia
    self.nombre=nombre
    self.edad=edad
  def saludar(self):
    print(f" Mi nombre es {self.nombre} y tengo {self.edad} años")
class Contador(Persona):
  empleo="contador"
  sueldo="5.000.000"
  def presentarse(self):
    self.saludar()
    print(f"Soy {self.empleo} y cobro {self.sueldo}")

# %% [markdown]
# ## Challenge 7 🤺 - 20 min
# Crear dos personajes de una historia que se representen a traves de clases. Ejemplo: Un hereo y un villano.
# Cada personaje debe tener poderes o acciones diferentes. Y deben presentarse en una frase.
#
# Ejemplo: Yo me llamo pepito y tengo super fuerza
# Ejemplo: Yo me llamo juanito y puedo volar

# %%
#Hago mi clase
class Mutantes:
    def __init__(self, nombre, poder):
#Atributos de instancia
        self.nombre = nombre
        self.poder = poder
class Bando(Mutantes):
    heroe = "Xmen"
    villano = "Hermandad de Mutantes"
    def presentacion(self, globo):
        self.globo = dialogo
        print(f"Soy {self.nombre}, un mutante, y tengo el poder de {self.poder}")
