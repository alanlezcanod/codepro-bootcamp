# %%
print('Hola mundo')
# Out:
# Hola mundo

# %%
# Orden de ejecucion:
fruta = "naranja"
print(fruta)

cantidad_de_frutas = 4
print(cantidad_de_frutas)

fruta = "banana"
print(fruta)
# Out:
# naranja
# 4
# banana

# %%
edad = 27 # --> Interger
altura = 1.73 # --> Float
nombre = "Alan" # --> String
feliz = True # --> Bool

#print(nombre)
#print(edad)
#print(altura)
#print(feliz)

print (edad, altura, nombre, feliz)
# Out:
# 27 1.73 Alan True

# %% [markdown]
# Challenge 🤺
# Crea 3 variables con tu nombre, edad y ciudad. Imprime en una sola línea usando print()

# %%
nombre = "Alan"
edad = 27
ciudad = "Fernando de la Mora"

print (nombre, edad, ciudad)
# Out:
# Alan 27 Fernando de la Mora

# %%
nombre = "Alan"
edad = "27"
ciudad = "Fernando de la Mora"

print (nombre + ' ' + edad + ' ' + ciudad)
# Out:
# Alan 27 Fernando de la Mora

# %%
nombre = "Alan"
edad = "27"
ciudad = "Fernando de la Mora"

print ("Me llamo", nombre,",", "tengo", edad, "años", "y soy de la ciudad de", ciudad)
# Out:
# Me llamo Alan , tengo 27 años y soy de la ciudad de Fernando de la Mora

# %% [markdown]
# Challenge 🤺 - 10m
#
# Suma: asignar dos números en dos variables diferentes cantidad_de_manzanas y cantidad_de_naranjas. Luego sumar ambas variables en cantidad_de_frutas. Imprimir la última variable.
#
# Resta: asignar un valor numérico a la variable frutas_vendidas. Luego, asignar la resta entre cantidad_de_frutas y frutas_vendidas a la variable frutas_restantes. Imprimir la última variable.

# %%
fruta = "manzanas"
cantidad_de_manzanas = 4

fruta = "naranjas"
cantidad_de_naranjas = 6

cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas
print("La cantidad de frutas totales son:", cantidad_de_frutas)

frutas_vendidas = 3
frutas_restantes = cantidad_de_frutas - frutas_vendidas
print("La cantidad de frutas no vendidas son:", frutas_restantes)
# Out:
# La cantidad de frutas totales son: 10
# La cantidad de frutas no vendidas son: 7

# %% [markdown]
# Challenge 🤺 - 10m
#
# Asignar el nombre y el apellido de tu compañera/o a las variables nombre y apellido. Luego, imprimir una frase, utilizando las variables.
# EJEMPLO: "Hola. Me llamo Claudia Melgarejo. Mucho gusto."

# %%
#Concatenacion

saludo = "Hola,"
nombre = "Benjamin"
apellido = "Cabrera"

print(f"{saludo} \n Mi compañero se llama {nombre}. \n Y su apellido es {apellido}")
# Out:
# Hola,
#  Mi compañero se llama Benjamin.
#  Y su apellido es Cabrera

# %%
#Concatenacion

saludo = "Hola,"
nombre = "Benjamin"
apellido = "Cabrera"

# %% [markdown]
# Challenge 🤺 - 8m
# Solicitar al usuario ingresar dos números y almacenarlos en dos variables. Luego, imprimir la suma de los dos números.

# %%
#Challenge 4

#Ingresar los numeros con 'int' al principio para que pase de String a Interger
var1 = int(input("ingrese un numero"))
var2 = int(input("ingrese otro numero"))

suma = ((var1) + (var2))
print(suma)
# Out:
# 30

# %%
#Ingresar los numeros con 'int' al principio para que pase de String a Interger
var1 = int(input("ingrese un numero"))
var2 = int(input("ingrese otro numero"))

suma = ((var1) + (var2))

#Impresion de ambos numeros ingresados para saber cuales fueron sumados
print("El primer valor ingresado es", var1 )
print("El segundo valo agregado es", var2 )

#Imprimir la suma de ambos numeros
print("La suma de los valores da",suma)
# Out:
# El primer valor ingresado es 10
# El segundo valo agregado es 20
# La suma de los valores da 30

# %% [markdown]
# Challenge 🤺 - 10m
#
# Crear una función de un proceso que se les ocurra que tenga varios pasos.
#
# Ejecutar la función 3 veces.Ejemplo preparar jugo de naranja..

# %%
def prender_el_aire():
    print("prendiendo el aire")
    print("la sala esta fria")
    print("apagando el aire")
    
#Orden 

prender_el_aire()
# Out:
# prendiendo el aire
# la sala esta fria
# apagando el aire

# %% [markdown]
# Challenge 🤺 - 25m
#
# Escribir una funcion que nos pregunte las caracteristicas de un elemento a comprar e imprima el elemento con sus caracteristicas.
# Debe de tener parametros y a la hora de llamar la accion debe de tener un argumento

# %%
#Declaramos una funcion con parametro
def servir_helado( sabor1, sabor2 ):
    print(f"Aqui tienes tu helado de: {sabor1} y {sabor2}")
          
         
 #Llamada a la funcion con argumento
servir_helado("chocolate", "vainilla")
servir_helado("dukce de leche", "granizado")
servir_helado("frutilla", "tramontana")
# Out:
# Aqui tienes tu helado de: chocolate y vainilla
# Aqui tienes tu helado de: dukce de leche y granizado
# Aqui tienes tu helado de: frutilla y tramontana

# %% [markdown]
# Challenge 🤺 - 10m
#
# 🎯 Objetivo:
# Escribir una función que pregunte por las características de un producto a comprar (por ejemplo, tipo, tamaño, color) e imprima un resumen de ese producto con las características ingresadas.
#
# Además, deben trabajar con variables locales y globales.

# %%
def buscar_producto(tipo, color, tamaño):
    print(f"Que tipo de ropa busca:{tipo}, de color {color} y de tamaño {tamaño}")

def buscar_producto():
 
tipo = input("Que tipo de ropa busca?")
color = input("De que color?")
tamaño = input("De que tamaño?")

print (f"Su producto es: {tipo}, {color}, {tamaño}")
# Out:
#   Cell In[32], line 6
#     tipo = input("Que tipo de ropa busca?")
#     ^
# IndentationError: expected an indented block after function definition on line 4
